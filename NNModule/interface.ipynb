# %%
"""@package interface
Documentation for this interface.

The basic interface for the NN model.
"""
from google.cloud import speech_v1p1beta1
from google.cloud.speech_v1p1beta1 import enums
import tensorflow


class Segments:
     """Documentation the Segments function.

    This function is used to split the input into 10ms.
    """
    pass
        

class Classification:
     """Documentation the Classification function.

    This function is used create node objects containing various properties.
    """
    pass
        
        
class DeviceNN:
     """Documentation the Device Neural Network function.

    This function is used train the device specific neural network.
    """
    pass
        
class ServerNN:
     """Documentation the Server Neural Network function.

    This function is used train the general specific neural network.
    """
    pass
